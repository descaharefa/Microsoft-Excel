# %% [markdown]
# # **BASIC FUNCTION PADA EXCEL**
# Nama : Desca W. Harefa

# %% [markdown]
# # **Penjelasan Fungsi-fungsi pada Excel**
#
# # 1. Fungsi Statistik Dasar
#
#
# *   **SUM**
#
#
# > Digunakan untuk menjumlahkan angka pada lembar kerja Microsoft Excel
#
#
# *   **AVERAGE**
#
# > Digunakan untuk mencari rata-rata dalam bentuk angka dari suatu data di Microsoft Excel
#
# *   **STANDAR DEVIASI**
#
# > Biasa juga dikenal dengan simpangan baku adalah rumus yang digunakan untuk mengukur keberagaman data
#
#
# *   **MAX & MIN**
#
# > Rumus yang digunakan untuk mencari nilai terendah dari beberapa data pada Microsoft Excel. Sebaliknya, rumus
#
#
#
# ```
# ```
#
# # 2. Fungsi Trim
#
# > Fungsi pada Microsoft Excel yang digunakan untuk menghilangkan spasi berlebih di Excel
#
# ```
# ```
#
# # 3. Fungsi Left & Right
#
# > Mengambil sebagaian karakter dari sebelah kiri atau kanan sel
#
#
# ```
# ```
#
# # 4. Fungsi Mid
#
# > Fungsi yang digunakan untuk mengambil sebagaian karakter yang berada di tengah-tengah sel
#
# ```
# ```
#
# # 5. Fungsi Rand
#
# > Membuat angka random atau acak pada Microsoft Excel
#
# ```
# ```
#
# # 6. Fungsi Rank
#
# > Untuk mencari peringkat atau ranking berdasarkan angka-angka yang ada dari sebuah data di Microsoft Excel
#
#
# ```
# ```
# # 7. Fungsi Count
#
# > Digunakan untuk menghitung banyaknya jumlah data pada sel yang di dalamnya terdapat angka.
#
# ```
# ```
#
# # 8. Fungsi CountIF
#
# > Untuk menghitung jumlah sel sesuai dengan kriteria yang kita masukkan di dalam formula di Microsoft Excel
#
#
# ```
# ```
#
# # 9. Fungsi Upper & Lower
#
# > Untuk mengubah huruf kecil menjadi huruf besar (kapital) dan mengubah huruf besar/kapital menjadi huruf kecil.
#
#
# ```
# ```
#
# # 10. Fungsi And Or
#
# > Salah satu fungsi logika untuk membandingkan 2 logika atau lebih sehingga menghasilkan sebuah nilai TRUE atau FALSE
#
#
# ```
# ```
#
# # 11. Fungsi If
#
# > Rumus IF dipakai untuk membandingkan logika terhadap nilai tertentu, dengan rumus fungsi IF kita bisa membandingkan logika yang kita masukkan
#
#
# ```
# ```
#
# # 12. Fungsi Concatenate
#
# > Fungsi yang digunakan untuk menggabungkan satu sel dengan sel-sel lain yang berisikan karakter teks/angka di Microsoft Excel
#
#
# ```
# ```
#
# # 13. Fungsi SumIF
#
# > Rumus yang digunakan untuk menjumlahkan angka berdasarkan ketentuan tertentu atau sesuai dengan kriteria yang dimasukkan
#
# ```
# ```
